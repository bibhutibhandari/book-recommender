# %%
import pandas as pd

# %%
popularity_ratings_filtered = pd.read_csv('../data/processed/popularity_ratings_filtered.csv')

# %%
popularity_ratings_filtered
# Out:
#              ISBN                       Book-Title         Book-Author  \
# 0      0399135782           The Kitchen God's Wife             Amy Tan
# 1      0399135782           The Kitchen God's Wife             Amy Tan
# 2      0399135782           The Kitchen God's Wife             Amy Tan
# 3      0399135782           The Kitchen God's Wife             Amy Tan
# 4      0399135782           The Kitchen God's Wife             Amy Tan
# ...           ...                              ...                 ...
# 43988  0613032950                    Animal Dreams  Barbara Kingsolver
# 43989  0394429869  I Know Why the Caged Bird Sings        Maya Angelou
# 43990  0449001164                      The Promise         CHAIM POTOK
# 43991  0743527631         The Pillars of the Earth         Ken Follett
# 43992  0745168086              The Handmaid's Tale     Margaret Atwood
#
#        Year-Of-Publication            Publisher  User-ID  Book-Rating
# ...

# %%
final_ratings = popularity_ratings_filtered.pivot_table(index= 'Book-Title', columns= 'User-ID', values= 'Book-Rating')

# %%
final_ratings
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# A Bend in the Road                                     0.0     NaN     7.0
# ...                                                    ...     ...     ...
# Without Remorse                                        NaN     NaN     NaN
# Wuthering Heights                                      NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
final_ratings.fillna(0,inplace=True)

# %%
final_ratings
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Without Remorse                                        0.0     0.0     0.0
# Wuthering Heights                                      0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
final_ratings.to_csv("../data/processed/final_ratings_pt.csv")
